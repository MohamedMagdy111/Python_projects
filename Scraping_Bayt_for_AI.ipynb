# %%
from bs4 import BeautifulSoup
import requests

# %%
site = requests.get("https://www.bayt.com/en/egypt/jobs/Ai%20Engineer-jobs/")
site
# Out:
# <Response [200]>

# %%
website=requests.get("https://www.bayt.com/en/egypt/jobs/Ai%20Engineer-jobs/").text
website
# Out:
# '<!doctype html>\n<html lang="en" dir="ltr">\n<head>\n<link rel="preconnect" href="https://secure.b8cdn.com">\n<link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin>\n<link rel="dns-prefetch" href="https://secure.b8cdn.com">\n<link rel="dns-prefetch" href="https://fonts.gstatic.com/">\n<meta name="keywords" content="ai engineer jobs in egypt, ai engineer vacancies egypt, ai engineer career opportunities in egypt">\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="copyright" content="Bayt.com, Inc.">\n<meta name="referrer" content="strict-origin-when-cross-origin">\n<meta property="fb:app_id" data-js-id="meta-fb_app_id" content="116830345011417">\n<meta property="og:site_name" data-js-id="meta-og_site_name" content="Bayt.com">\n<meta property="og:title" data-js-id="meta-og_title" content="Ai Engineer Jobs in Egypt  (2024) - Bayt.com">\n<meta property="og:image:secure_url" data-js-id="meta-og_image_secure_url" content="https://secure.b8cdn.com/images/logos/fb_bayt_new_en.png">\n<meta property="og:image" data-js-id="meta-og_image" content="http://secure.b8cdn.com/images/logos/fb_bayt_new_en.png">\n<meta property="og:description" data-js-id="meta-og_description" content="Apply now to over 50 Ai Engineer jobs in Egypt and make your job hunting simpler. Find the latest Ai Engineer job vacancies and employment opportunities in Egypt.">\n<meta data-js-id="meta-description" name="description" content="Apply now to over 50 Ai Engineer jobs in Egypt and make your job hunting simpler. Find the latest Ai Engineer job vacancies and employment opportunities in Egypt.">\n<meta property="og:url" data-js-id="meta-og_url" content="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/">\n<meta data-js-id="meta-twitter_card" name="twitter:card" content="summary">\n<meta data-js-id="meta-twitter_site" name="twitter:site" content="@Baytcom">\n<link data-js-id="link-next" rel="next" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/?page=2">\n<link rel="manifest" href="/push-notifications/app/manifest.json">\n<link rel="icon" href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/favicon.ico" sizes="any">\n<link rel="icon" href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/favicon.svg" type="image/svg+xml">\n<link rel="apple-touch-icon" href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/apple-touch-icon.png">\n<link data-js-id="link-canonical" rel="canonical" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/">\n<link hreflang="x-default" data-js-id="link-x-default" rel="alternate" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/">\n<link hreflang="en" data-js-id="link-en" rel="alternate" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/">\n<link hreflang="ar" data-js-id="link-ar" rel="alternate" href="https://www.bayt.com/ar/egypt/jobs/Ai+Engineer-jobs/">\n<style>\n/*<![CDATA[*/\n@media screen{.print-only{display:none!important}}@media screen and (min-width:1024px){.search-bar:not(.is-active).is-compact>.input-pack,.search-bar:not(.is-active)>.b-close,.search-bar:not(.is-compact)>.b-search{display:none}}.has-icon{position:relative}.has-icon>.icon{position:absolute;top:50%;right:12px;margin:auto;transform:translateY(-50%)}.has-icon.to-left>.icon{right:auto;left:10px}.popover{display:none}.icon{min-width:18px}.slider{position:relative}.slider-arrow{color:transparent}.slider-arrows{position:absolute}.t-danger{color:#ff3b30}.h3,h1,h2,h4,h6{line-height:1.2;margin:0 0 .5em;color:#000}.list.is-basic,.list.is-basic>li{padding-left:0}.accordion-toggle:checked+.accordion-title,.btn,.btn.is-large,.btn.is-small,.btn.is-xsmall,.t-bold{font-weight:700}.popover,nav>.nav{text-align:left}.dropdown,.list.is-basic,.media-list,.nav{list-style:none}.btn,.input,.msg-actions,.nav>li>a>.icon,.pagination>li,input.switch+label{vertical-align:middle}.accordion-title,.dropdown>li>a,.pagination>li>a,a{text-decoration:none}.btn,.dropdown>li>a,.label,.msg-acti ...

# %%
website=BeautifulSoup(website,"lxml")
website
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <link href="https://secure.b8cdn.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <link href="https://secure.b8cdn.com" rel="dns-prefetch"/>
# <link href="https://fonts.gstatic.com/" rel="dns-prefetch"/>
# <meta content="ai engineer jobs in egypt, ai engineer vacancies egypt, ai engineer career opportunities in egypt" name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Bayt.com, Inc." name="copyright"/>
# <meta content="strict-origin-when-cross-origin" name="referrer"/>
# <meta content="116830345011417" data-js-id="meta-fb_app_id" property="fb:app_id"/>
# <meta content="Bayt.com" data-js-id="meta-og_site_name" property="og:site_name"/>
# <meta content="Ai Engineer Jobs in Egypt  (2024) - Bayt.com" data-js-id="meta-og_title" property="og:title"/>
# <meta content="https://secure.b8cdn.com/images/logos/fb_bayt_new_en.png" data-js-id="meta-og_image_secure_url" property="og:image:secure_url"/>
# <meta content="http://secure.b8cdn.com/images/logos/fb_bayt_new_en.png" data-js-id="meta-og_image" property="og:image"/>
# <meta content="Apply now to over 50 Ai Engineer jobs in Egypt and make your job hunting simpler. Find the latest Ai Engineer job vacancies and employment opportunities in Egypt." data-js-id="meta-og_description" property="og:description"/>
# <meta content="Apply now to over 50 Ai Engineer jobs in Egypt and make your job hunting simpler. Find the latest Ai Engineer job vacancies and employment opportunities in Egypt." data-js-id="meta-description" name="description"/>
# <meta content="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/" data-js-id="meta-og_url" property="og:url"/>
# <meta content="summary" data-js-id="meta-twitter_card" name="twitter:card"/>
# <meta content="@Baytcom" data-js-id="meta-twitter_site" name="twitter:site"/>
# <link data-js-id="link-next" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/?page=2" rel="next"/>
# <link href="/push-notifications/app/manifest.json" rel="manifest"/>
# <link href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/favicon.ico" rel="icon" sizes="any"/>
# <link href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="//secure.b8cdn.com/bayt/assets/b8static/favicon/js/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link data-js-id="link-canonical" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/" rel="canonical"/>
# <link data-js-id="link-x-default" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/" hreflang="x-default" rel="alternate"/>
# <link data-js-id="link-en" href="https://www.bayt.com/en/egypt/jobs/Ai+Engineer-jobs/" hreflang="en" rel="alternate"/>
# <link data-js-id="link-ar" href="https://www.bayt.com/ar/egypt/jobs/Ai+Engineer-jobs/" hreflang="ar" rel="alternate"/>
# <style>
# /*<![CDATA[*/
# @media screen{.print-only{display:none!important}}@media screen and (min-width:1024px){.search-bar:not(.is-active).is-compact>.input-pack,.search-bar:not(.is-active)>.b-close,.search-bar:not(.is-compact)>.b-search{display:none}}.has-icon{position:relative}.has-icon>.icon{position:absolute;top:50%;right:12px;margin:auto;transform:translateY(-50%)}.has-icon.to-left>.icon{right:auto;left:10px}.popover{display:none}.icon{min-width:18px}.slider{position:relative}.slider-arrow{color:transparent}.slider-arrows{position:absolute}.t-danger{color:#ff3b30}.h3,h1,h2,h4,h6{line-height:1.2;margin:0 0 .5em;color:#000}.list.is-basic,.list.is-basic>li{padding-left:0}.accordion-toggle:checked+.accordion-title,.btn,.btn.is-large,.btn.is-small,.btn.is-xsmall,.t-bold{font-weight:700}.popover,nav>.nav{text-align:left}.dropdown,.list.is-basic,.media-list,.nav{list-style:none}.btn,.input,.msg-actions,.nav>li>a>.icon,.pagination>li,input.switch+label{vertical-align:middle}.accordion-title,.dropdown>li>a,.pagination>li>a,a{text-decoration:none}.btn,.dropdown>li>a,.label,.msg-actions,.nav>li>a,.t-nowrap{white-space:nowrap}@font-face{font-family:icons;src:url(https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/css/Simple-Line-Icons-Pro.eot);src:url(https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/css/Simple-Line-Icons-Pro.woff2) format("woff2"),url(https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/css/Simple-Line-Icons-Pro.ttf) format("truetype"),url(https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/css/Simple-Line-Icons-Pro.woff) format("woff"),url(https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/css/Simple-Line-Icons-Pro.eot#iefix) format("embedded-opentype"),url(https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/css/Simple-Line-Icons-Pro.svg#test) format("svg");font-weight:400;font-style:normal;font-display:swap}@font-face{font-family:Lato;font-style:normal;font-weight:300;src:local("Lato Light"),local("Lato-Light"),url(//fonts.gstatic.com/s/lato/v14/dPJ5r9gl3kK6ijoeP1IRsvY6323mHUZFJMgTvxaG2iE.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+20A0-20AB,U+20AD-20CF,U+2C60-2C7F,U+A720-A7FF;font-display:swap}@font-face{font-family:Lato;font-style:normal;font-weight:300;src:local("Lato Light"),local("Lato-Light"),url(//fonts.gstatic.com/s/lato/v14/EsvMC5un3kjyUhB9ZEPPwg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2212,U+2215;font-display:swap}@font-face{font-family:Lato;font-style:normal;font-weight:400;src:local("Lato Regular"),local("Lato-Regular"),url(//fonts.gstatic.com/s/lato/v14/UyBMtLsHKBKXelqf4x7VRQ.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+20A0-20AB,U+20AD-20CF,U+2C60-2C7F,U+A720-A7FF;font-display:swap}@font-face{font-family:Lato;font-style:normal;font-weight:400;src:local("Lato Regular"),local("Lato-Regular"),url(//fonts.gstatic.com/s/lato/v14/1YwB1sO8YE1Lyjf12WNiUA.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2212,U+2215;font-display:swap}@font-face{font-family:Lato;font-style:normal;font-weight:700;src:local("Lato Bold"),local("Lato-Bold"),url(//fonts.gstatic.com/s/lato/v14/ObQr5XYcoH0WBoUxiaYK3_Y6323mHUZFJMgTvxaG2iE.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+20A0-20AB,U+20AD-20CF,U+2C60-2C7F,U+A720-A7FF;font-display:swap}@font-face{font-family:Lato;font-style:normal;font-weight:700;src:local("Lato Bold"),local("Lato-Bold"),url(//fonts.gstatic.com/s/lato/v14/H2DMvhDLycM56KNuAtbJYA.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2212,U+2215;font-display:swap}@font-face{font-family:'Noto Kufi Arabic';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/ea/notokufiarabic/v2/NotoKufiArabic-Regular.eot);src:url(//fonts.gstatic.com/ea/notokufiarabic/v2/NotoKufiArabic-Regular.eot?#iefi ...
# /*]]>*/
# </style>
# <script>!function(n){var a=[],e=setInterval(function(){if(B8.v){for(var n;n=a.pop();)B8.ready(n);clearInterval(e)}},100);n.B8=n.B8||{ready:function(n){a.push(n)}}}(window);B8v={"domainType":"jobs","cookiesDomain":".bayt.com","devProjects":{"generic":0,"yiiBetaAndDev":0,"baytUIProfile":1,"jsMicroCvBuilder":1,"newWhatsappFlow":0,"freemium_project":true},"pageCached":true,"saveNav":false,"amplitudeApiKey":"6e362603a9c35b5505d9ce2047990487","jsCdnRoot":"\/\/secure.b8cdn.com","B8trkUrl":"https:\/\/trk.bayt.com","ssdcookie":"SSD0","isShagheelUrl":false,"adsenseCSA":{"pageOptions":{"channel":6339614250,"query":"Ai Engineer Jobs in Egypt","hl":"en","adPage":1,"adtest":"off","styleId":"3741995929"},"ads":[{"block":{"container":"adsenseCSA_BTF_en","number":3}}]},"firebase":{"files":[{"id":485836676,"file":"https:\/\/www.gstatic.com\/firebasejs\/7.8.1\/firebase-app.js"},{"id":3440100177,"file":"https:\/\/www.gstatic.com\/firebasejs\/7.8.1\/firebase-messaging.js"}],"config":{"firebaseConfig":{"apiKey":"AIzaSyB0mE5ok6flEiUrp-I8ENZ0wjbbjatP1kM","authDomain":"bayt-com-api-project-690072141335.firebaseapp.com","databaseURL":"https:\/\/bayt-com-api-project-690072141335.firebaseio.com","projectId":"bayt.com:api-project-690072141335","storageBucket":"undefined","messagingSenderId":"690072141335","appId":"1:690072141335:web:b54325063687927189e652","measurementId":"G-C2STKV07BY"},"publicVapidKey":"BHNvLdnKk5ozRNy9C-FpKjWIlHrInxRsh9IaAwYEKvYyFRQblbduZCZg5ffn56wibWFgGwQm2zcosg-c1ZR09hI"},"notifScript":{"id":3002943421,"file":"\/bayt\/assets\/baytui-8ebnt3um\/js\/webPushNotifications.js"}},"gpt":{"ads":["ad_listing_1"],"targets":{"lang":"en","url":"en egypt jobs Ai Engineer jobs"},"slot":"","sizeMap":{"ad_listing_1":{"s":"listing_1","m":[[[480,0],["fluid",[336,280],[300,250]]],[[320,0],["fluid",[300,600],[300,250]]],[[0,0],["fluid",[250,250],[200,200]]]]}}},"globalSearchVars":{"page":0,"jobAlertScript":"https:\/\/secure.b8cdn.com\/bayt\/assets\/userregistration-88qvsd5d\/js\/registerJobAlert.js","showJA":true,"clickedFacet":""},"deleteAllMessage":"<h5>Confirm unsaving your Saved Jobs<\/h5><p>This action will remove all jobs in your Saved Jobs list. Are you sure you want to continue?<\/p>","deleteAllMessageOk":"OK","deleteAllMessageCancel":"Cancel","showPopupAfterJobAlert":false,"csrf":{"token":"6826a96097c04718abddb4aae968757f5b81f987"},"cdn":{"CdnDomain":"\/\/secure.b8cdn.com","HttpsCdnDomain":"https:\/\/secure.b8cdn.com","cssCdnRoot":"\/\/secure.b8cdn.com","imagesCdnRoot":"\/\/secure.b8cdn.com\/images","jsCdnRoot":"\/\/secure.b8cdn.com","HttpsEmailCdn":"https:\/\/secure.b8cdn.com"},"ext":{"oneTapGmail":true},"view":{"userConfirmationScript":"https:\/\/secure.b8cdn.com\/bayt\/assets\/userconfirmation-e767v347\/js\/userConfirmationBaytUI.js","registerJobAlertScript":"https:\/\/secure.b8cdn.com\/bayt\/assets\/userregistration-88qvsd5d\/js\/registerJobAlert.js","fromJobSearch":"\/en\/egypt\/jobs\/Ai+Engineer-jobs\/","confirmDeleteMsg":"This application will be deleted. Are you sure you want to continue?","bttnCloseText":"Close","emptyEmailAddress":"No email address provided","invalidEmailAddress":"Email address is invalid","resendConfirmEmailMssg":"Confirm your email address to start applying to jobs","resendConfirmationButton":"Resend Confirmation Email","usedEmailAddress":"Email address is already used","goBackBtn":"Go Back","okText":"OK","cancelText":"Cancel","savedLink":"<i class='icon is-star'><\/i>Saved","shareWithYourFriends":"Share with Your Friends","applyLocalText1":"This job is for locals only","jobAlertRegisterParamsOfUrl":"{&quot;p&quot;:[&quot;eg&quot;],&quot;v&quot;:&quot;ai engineer&quot;}"},"searchHistory":[],"searchSlugs":[{"countryInUrl":"algeria"},{"countryInUrl":"bahrain"},{"countryInUrl":"bahrain","cityInUrl":"manama"},{"countryInUrl":"egypt"},{"countryInUrl":"egypt","cityInUrl":"alexandria"},{"countryInUrl":"egypt","cityInUrl":"cairo"},{"countryInUrl":"india"},{"countryInUrl":"iraq"},{"countryInUrl":"iraq","cityInUrl":"baghdad"}, ...
# <title data-js-id="meta-title">Ai Engineer Jobs in Egypt (2024) - Bayt.com</title>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# </head>
# <body class="fixed-nav"><script defer="defer" id="3266630135" src="https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/js/eventsDataCollector.js"></script>
# <div class="no-print" data-cancel_on_tap_outside="false" data-client_id="690072141335.apps.googleusercontent.com" data-context="use" data-current_query_string="" data-login_uri="https://www.bayt.com/ajax/user-login/user-login/one-tap-login/" data-prompt_parent_id="g_id_onload" data-referrer_url="en/egypt/jobs/Ai Engineer-jobs" data-state_cookie_domain=".bayt.com" id="g_id_onload" style="position:fixed;top:84px;right:8px;z-index:9999;direction:ltr;">
# </div>
# <nav data-bayt-scrolllock="8" data-scrolllock='{"unblock":"ul.nav.is-active,.no-capture-right,.list-menu-group"}' id="baytNav">
# <ul class="nav" data-nav='{"autoHide":false}' id="navList" style="align-items:center">
# <li class="m" data-bars="">
# <a aria-label="Menu" class="is-toggle" href="#"><i class="icon is-bars m0"></i></a>
# </li>
# <li class="is-wide-m">
# <a class="is-logo u-iblock" href="https://www.bayt.com/" id="baytLogo">
# <img alt="Bayt.com" class="" height="35" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%2026.19%205.56'%3E%3Cpath%20fill='%23fff'%20fill-rule='evenodd'%20d='M11.97%204.8c-.25%200-.45-.23-.45-.52%200-.3.2-.5.45-.5h2.87v.4a.6.6%200%200%201-.58.62zm2.29-3.56h-3.48v.77h3.48c.33-.01.6.26.58.62V3h-2.87c-.66%200-1.19.56-1.2%201.27.01.7.54%201.28%201.2%201.28h2.29c.74%200%201.32-.63%201.33-1.39V2.63c-.01-.77-.59-1.4-1.33-1.39zm5.9%200h.74v2.91c-.01.78-.6%201.4-1.35%201.4h-3.4V4.8h3.4c.33%200%20.6-.3.6-.65V3.8h-2.67c-.74%200-1.33-.64-1.33-1.42V1.24h.75v1.13c-.01.35.25.64.57.64h2.69zM6.73%204.8c-.32%200-.58-.28-.59-.63v-.39h2.9c.24%200%20.44.2.43.5%200%20.29-.19.52-.43.52zm-.59-1.79V1.24H5.4v2.93c0%20.76.6%201.39%201.33%201.39h2.31c.65%200%201.18-.58%201.17-1.28%200-.7-.52-1.28-1.17-1.27zm20.05%200v.78H22.2v.36c-.01.36.27.65.6.65h3.38v.76H22.8c-.74%200-1.33-.63-1.34-1.4V1.23h.74v1.77z'/%3E%3Cpath%20fill='%23ffd42a'%20fill-rule='evenodd'%20d='M0%201.8%202.39.54l2.38%201.24v-.55L2.4%200%200%201.24Z'/%3E%3C/svg%3E" width="99"/>
# </a>
# </li>
# <li class="m">
# <a class="btn is-round is-inverse is-xsmall" href="https://bayt.page.link/nav" id="navUseAppBtn" rel="nofollow">
# USE APP	</a>
# </li>
# <li class="is-wide-d">
# <ul class="nav is-main can-toggle" data-capture="" data-toggle-bars="" id="yw0">
# <li><a href="https://www.bayt.com/en/egypt/">Home</a></li>
# <li class="popover-owner has-pointer has-inline is-selected" data-popover=""><a href="https://www.bayt.com/en/egypt/jobs/search/">Find Jobs</a>
# <ul class="popover is-inline dropdown p0y-m t-small-d t-regular-m in-nav" data-placement="bl">
# <li><a href="https://www.bayt.com/en/egypt/jobs/search/">Find Jobs</a></li>
# <li class="is-title t-mute"><span>Browse Jobs</span></li>
# <li><a href="https://www.bayt.com/en/egypt/jobs/sectors/" rel="nofollow">Jobs by Sector</a></li>
# <li><a href="https://www.bayt.com/en/jobs/locations/">Jobs by Location</a></li>
# <li class="d"><a href="https://www.bayt.com/en/egypt/companies/">Jobs by Companies</a></li>
# <li><a href="https://www.bayt.com/en/egypt/jobs/executive-level-jobs/">Executive Jobs<span class="u-right"><i class="icon is-tie"></i></span></a></li>
# <li><a href="https://www.bayt.com/en/egypt/jobs/work-from-home/">Work from Home Jobs</a></li>
# <li><a href="https://www.bayt.com/en/egypt/salaries/">Salaries</a></li>
# </ul>
# </li>
# <li class="d"><a href="https://www.bayt.com/en/register-j/?native_source=CreateYourCV">Create Your CV</a></li>
# <li class="popover-owner has-pointer has-inline" data-popover=""><a href="https://www.bayt.com/en/blog/">Blog</a>
# <ul class="popover is-inline dropdown p0y-m t-small-d t-regular-m in-nav" data-placement="bl">
# <li><a href="https://www.bayt.com/en/blog/category/job-search-tips-1489187/">Job Search Tips</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/the-powerful-cv-1489194/">The Powerful CV</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/interviews-and-offers-1489195/">Interviews and Offers</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/grow-your-career-1489197/">Grow Your Career</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/market-knowledge-1739/">Market Knowledge</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/employer-corner-1418873/">Employer Corner</a></li>
# <li><a href="https://www.bayt.com/en/blog/category/press-releases-12828/">Press Releases</a></li>
# </ul>
# </li>
# <li class="popover-owner has-pointer has-inline" data-popover=""><a href="https://www.bayt.com/en/cv-writing/?native_source=CVW-top-menu">CV Services</a>
# <ul class="popover is-inline dropdown p0y-m t-small-d t-regular-m in-nav" data-placement="bl">
# <li><a href="https://www.bayt.com/en/cv-writing/?native_source=CVW-top-menu">Professional CV Writing</a></li>
# <li><a href="https://www.bayt.com/en/cv-writing/visual-cvs/?native_source=CVW-top-menu">Visual CV Templates</a></li>
# <li><a href="https://www.bayt.com/en/cv-writing/cover-letter/">Cover Letter Writing</a></li>
# <li><a href="https://www.bayt.com/en/cv-writing/cv-evaluation/">CV Evaluation</a></li>
# <li class="has-divider p10x d"><a class="btn is-success t-small" href="https://www.bayt.com/en/premium/?native_source=nav"><span class="t-inverse"><i class="icon is-crown"></i> Upgrade to Premium</span></a></li>
# </ul>
# </li>
# <li class="popover-owner has-pointer has-inline" data-more="" data-popover="" style="display:none;"><a href="#">More</a>
# <div class="popover is-inline" data-bayt-popover="4" data-placement="bl">
# <ul class="dropdown p0-m t-small-d t-regular-m in-nav"></ul>
# </div></li>
# <li class="is-wide-d"><span></span></li>
# <li class="is-group">
# <ul class="list is-inline is-basic is-spaced t-nowrap">
# <li><a class="btn is-small is-inverse u-expanded-m" href="https://www.bayt.com/en/login/">Log In</a></li>
# <li class="d"><a class="btn is-small is-inverse is-outline u-expanded-m d" href="https://www.bayt.com/en/register-j/">Register</a></li>
# <li class="m"><a class="btn is-small is-outline u-expanded-m m" href="https://www.bayt.com/en/register-j/">Register</a></li>
# <li class="d"><a class="btn is-small is-inverse is-outline u-expanded-m d" href="https://www.bayt.com/en/employers/">For Employers</a></li>
# </ul>
# </li>
# <li class="is-first">
# <ul class="nav is-aux">
# <li class="is-wide-m m"><a aria-label="Close" class="b-close" data-nav-close="" href="#"></a></li>
# <li class="popover-owner" data-popover='{"relocate":true, "trigger":"click"}'><a aria-label="Apps" href="#"><i class="icon is-apps"></i> </a><div class="popover is-pointing is-full" data-placement="br">
# <div class="list-menu">
# <div class="list-menu-title">
# <a class="b-close is-large t-mute u-abs m" data-popover-close="" href="#"></a>
# <h6 class="t-center-m m0"> Products By Bayt.com </h6>
# </div>
# <div class="list-menu-group t-center" data-empty="Nothing up to now!">
# <div class="row is-m dark-links">
# <a class="col is-4" href="https://www.bayt.com">
# <img alt="Bayt.com" class="img-apps is-b" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Bayt.com</div>
# </a>
# <a class="col is-4" href="https://shagheel.bayt.com/">
# <img alt="Shagheel" class="img-apps is-shagheel" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Shagheel</div>
# </a>
# <a class="col is-4" href="https://specialties.bayt.com/">
# <img alt="Specialities" class="img-apps is-specialties" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Specialities</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/courses/learning-home/">
# <img alt="Learning" class="img-apps is-learning" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Learning</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/company/">
# <img alt="Companies" class="img-apps is-companies" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Companies</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/egypt/salaries/">
# <img alt="Salaries" class="img-apps is-salaries" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Salaries</div>
# </a>
# <a class="col is-4" href="https://people.bayt.com/">
# <img alt="People" class="img-apps is-people" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">People</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/blog/">
# <img alt="Blog" class="img-apps is-blog" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Blog</div>
# </a>
# <a class="col is-4" href="https://www.bayt.com/en/podcast/video/">
# <img alt="Podcasts" class="img-apps is-podcast" height="40" src="//secure.b8cdn.com/bayt/assets/b8static/png/1.png" width="40"/>
# <div class="m10t">Podcasts</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li><span></span></li>
# <li>
# <ul class="nav is-aux is-small">
# <li><a data-js-tolang="ar" href="/ar/egypt/jobs/Ai+Engineer-jobs/" id="en-language" onclick="BaytNavigation.changeLanguage(this, 0); return false;">العربية</a></li>
# </ul>
# </li>
# <li class="m"><section class="m t-center m10t bg-inverse jsMobilePromotions u-none">
# <div class="card">
# <div class="card-head p10t">
# <i class="t-primary icon is-smartphone is-48 m0"></i>
# <h4 class="m10y">Use Our Mobile App </h4>
# </div>
# <div class="card-content">
# <p class="m0">Get contacted by recruiters directly with our newest chat feature!</p>
# </div>
# <div class="card-foot">
# <a class="btn m20b u-expanded-m" href="https://bayt.page.link/m-menu">Download Now</a>
# </div>
# </div>
# </section>
# </li>
# </ul> </li>
# <li class="m p10">
# </li>
# </ul>
# </nav>
# <div class="t-center print-only p10t"><img alt="Bayt.com" loading="lazy" src="//secure.b8cdn.com/bayt/assets/b8static/svg/bayt-logo.svg"/></div>
# <div class="bg-inverse-d is-wide p20y-d p10-m">
# <div class="box p0">
# <form action="https://www.bayt.com/en/jobs/" class="search-bar" data-action="~/" id="form" method="get" onsubmit="event.preventDefault(); submitSearch(this);">
# <div class="row is-compact is-m">
# <div class="col is-5-d is-12-m">
# <div class="searchable has-icon to-left">
# <input aria-label="keyword" autocomplete="off" class="input is-large p20l-m" data-searchable='
# 					{
# 						"view": {
# 							"render": "searchControl.renderItem",
# 							"highlight": true,
# 							"placement": "bl",
# 							"placeholder":"Start your search by typing into the search box above",
# 							"autoActivate":false
# 						},
# 						"on":{
# 							"close": "searchControl.selectItem"
# 						},
# 						"data": {
# 							"format":"searchControl.getValue",
# 							"static": false,
# 							"fetch": "searchControl.autoComplete",
# 							"delay": 400,
# 							"text" : "title",
# 							"value": "id",
# 							"group": "group",
# 							"search": "*",
# 							"history":true
# 						}
# 					}
# 					' id="text_search" name="keyword" placeholder="Search jobs, skills, companies" type="text" value="ai engineer"/>
# <i class="icon is-search d"></i> <input aria-label="search" name="composite_search" type="hidden" value="1"/>
# </div>
# </div>
# <div class="col is-5-d is-10-m">
# <div class="select has-icon to-left">
# <select aria-label="select country" class="input is-large spec-con-input" data-searchable='{"data":{"group":"group" , "selected":"egypt"},"view":{"name":"$1"}, "optional":false}' data-value="egypt" id="search_country" name="country">
# <option disabled="" value="non">Select location</option>
# <option selected="" value="international">All locations</option>
# <option value="algeria">Algeria</option>
# <option value="bahrain">Bahrain</option>
# <option value="manama">Bahrain - Manama</option>
# <option selected="" value="egypt">Egypt</option>
# <option value="alexandria">Egypt - Alexandria</option>
# <option value="cairo">Egypt - Cairo</option>
# <option value="india">India</option>
# <option value="iraq">Iraq</option>
# <option value="baghdad">Iraq - Baghdad</option>
# <option value="jordan">Jordan</option>
# <option value="amman">Jordan - Amman</option>
# <option value="kuwait">Kuwait</option>
# <option value="al-kuwait">Kuwait - Al Kuwait</option>
# <option value="lebanon">Lebanon</option>
# <option value="beirut">Lebanon - Beirut</option>
# <option value="libya">Libya</option>
# <option value="morocco">Morocco</option>
# <option value="casablanca">Morocco - Casablanca</option>
# <option value="oman">Oman</option>
# <option value="muscat">Oman - Muscat</option>
# <option value="pakistan">Pakistan</option>
# <option value="qatar">Qatar</option>
# <option value="doha">Qatar - Doha</option>
# <option value="saudi-arabia">Saudi Arabia</option>
# <option value="dammam">Saudi Arabia - Dammam</option>
# <option value="eastern-province">Saudi Arabia - Eastern Province</option>
# <option value="jeddah">Saudi Arabia - Jeddah</option>
# <option value="jubail">Saudi Arabia - Jubail</option>
# <option value="khobar">Saudi Arabia - Khobar</option>
# <option value="mecca">Saudi Arabia - Mecca</option>
# <option value="medina">Saudi Arabia - Medina</option>
# <option value="riyadh">Saudi Arabia - Riyadh</option>
# <option value="sri-lanka">Sri Lanka</option>
# <option value="tunisia">Tunisia</option>
# <option value="tunis">Tunisia - Tunis</option>
# <option value="uae">United Arab Emirates</option>
# <option value="abu-dhabi">United Arab Emirates - Abu Dhabi</option>
# <option value="ajman">United Arab Emirates - Ajman</option>
# <option value="al-ain">United Arab Emirates - Al Ain</option>
# <option value="dubai">United Arab Emirates - Dubai</option>
# <option value="fujairah">United Arab Emirates - Fujairah</option>
# <option value="ras-al-khaimah">United Arab Emirates - Ras Al Khaimah</option>
# <option value="sharjah">United Arab Emirates - Sharjah</option>
# <option value="yemen">Yemen</option>
# </select>
# <i class="icon is-location"></i>
# </div>
# </div>
# <div class="col is-2">
# <button class="btn is-large u-expanded" data-js-aid="search" type="submit">
# <i class="icon is-search m0 m"></i><span class="d">Find Jobs</span> </button>
# </div>
# </div>
# </form> </div>
# </div>
# <div id="popTemp"></div>
# <div class="box is-wide row is-reversed-d is-collapsed-m no-wrap">
# <div class="col is-9-d is-half sticky-sense u-none" id="jsMiniJobView">
# <div id="formToggleSheet">
# <!-- Job Vi	ew-->
# <div id="view_inner">
# </div>
# <div class="u-none" id="toggleFooter"></div>
# </div>
# </div>
# <div class="col is-9-d sticky-sense" id="jsMainListingContainer">
# <div class="sticky-sidebar" data-sticky-sidebar="">
# <!-- Job Results-->
# <div class="sticky-content" id="results_inner">
# <!-- Job Results-->
# <div class="card">
# <div class="card-head">
# <h1 class="h3" data-automation-id="heading1">Ai Engineer Jobs in Egypt</h1>
# <div class="row v-align-center-d h-align-between">
# <b class="m20b-m">
# 50 jobs found	</b>
# <div class="row is-m h-align-between-m h-align-right-d">
# <a class="btn m" href="#" id="filter">
# Filter	</a>
# <div class="popover-owner u-iblock" data-popover='{"trigger":"click"}'>
# <div class="btn is-clear p0x">
# <span class="t-medium">
# Sort by: <b>Relevance</b><i class="icon is-arrow-down m0 m5l"></i>
# </span>
# </div>
# <div class="popover" data-placement="br">
# <ul class="dropdown">
# <li><a href="/en/egypt/jobs/ai-engineer-jobs/?options%5Bsort%5D%5B%5D=r" rel="nofollow">Relevance</a></li>
# <li class="has-divider"><a href="/en/egypt/jobs/ai-engineer-jobs/?options%5Bsort%5D%5B%5D=d" rel="nofollow">Date</a></li>
# <li class="has-divider"><a href="/en/egypt/jobs/ai-engineer-jobs/?options%5Bsort%5D%5B%5D=l" rel="nofollow">Language</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card-content" id="results_inner_card">
# <ul class="media-list in-card is-spaced is-divided is-reversed has-hover-d has-rects has-free-img bb" data-empty="Nothing available">
# <li class="is-attached to-screen is-inner u-shade-m p0 bg-inverse" data-position-d="n" data-position-m="b">
# <div class="row is-m no-wrap v-align-center p0y-d p10y-m p10x bg-lite">
# <div class="col u-expanded t-large t-bold p10l">
# <span class="">Create a job alert for similar positions</span>
# </div>
# <div class="col t-right p0">
# <input class="switch is-small" id="jobAlertSwitch" onclick="showRegisterJobAlertPopup(false , '1');" type="checkbox"/><label for="jobAlertSwitch"></label>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70988978" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70988978" data-js-jobheartstatus="" data-savelinklatter="70988978" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-ai-engineer-70988978/">
# Senior AI Engineer	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">PaxeraHealth</b>
# <span class="jb-loc t-mute t-nowrap u-block">Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# have what they need. The <b>AI Engineer</b> is responsible for understanding the ... problems, identifying/applying the right <b>AI</b> or cognitive computing technologies. In ...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 2 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70990742" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70990742" data-js-jobheartstatus="" data-savelinklatter="70990742" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-software-engineer-ai-training-remote-70990742/">
# Senior Software Engineer - AI Training - Remote	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Remotebase</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Start your interview for this role here We have partnered with an organization to train large AI language models, helping cutting-edge…	</div>
# <div class="jb-tags m0t">
# <dl class="dlist is-spaced t-small m10y">
# <dt class="p0 m10r"><i class="icon p5b is-home t-mute m5r"></i><span class="t-bold p5l">Work from Home</span></dt>
# </dl>
# </div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 2 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70628864" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70628864" data-js-jobheartstatus="" data-savelinklatter="70628864" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/ai-software-engineer-backend-70628864/">
# AI Software Engineer - [Backend]	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Envisions Employment Solutions</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Ready and hungry for a new adventure? You are definitely in the right place! We at Envision Employment Solutions are always on the…	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 30+ days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="71001600" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="71001600" data-js-jobheartstatus="" data-savelinklatter="71001600" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-machine-learning-engineer-71001600/">
# Senior Machine Learning Engineer	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Procore Technologies, Inc</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# looking for a talented software <b>engineer</b>, ML Platform to join Procore ... . As a Senior Machine Learning <b>Engineer</b> on our ML Platform team ... of services needed to release <b>AI</b>...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# Yesterday	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70999795" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70999795" data-js-jobheartstatus="" data-savelinklatter="70999795" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-software-engineer-python-70999795/">
# Senior Software Engineer (Python)	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Clarivate</b>
# <span class="jb-loc t-mute t-nowrap u-block">Alexandria, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# for a Senior Python Software <b>Engineer</b> to join our innovative and ... supporting cutting edge Artificial Intelligence (<b>AI</b>) &amp; Image Search products, and ...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# Yesterday	</div>
# </div>
# </div>
# </li>
# <li class="m t-center">
# <a class="btn is-secondary is-outline is-large is-round u-expanded-m" href="javascript:;" onclick="JobSearch.showMainThirdColumnHtml();">
# Build your CV in just a few clicks	<i class="icon is-arrow-right m5x"></i>
# </a>
# </li>
# <li class="has-pointer-d" data-job-id="71005323" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="71005323" data-js-jobheartstatus="" data-savelinklatter="71005323" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/engineering-manager-outsystems-egypt-71005323/">
# Engineering Manager-Outsystems – Egypt	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Linkdev</b>
# <span class="jb-loc t-mute t-nowrap u-block">Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Digital Experience Operational Excellence Dynamics 365 &amp; Business Apps Data &amp; Analytics Cloud &amp; Infrastructure Outsourcing…	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 15 hours ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="71005724" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="71005724" data-js-jobheartstatus="" data-savelinklatter="71005724" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-software-engineer-fintech-71005724/">
# Senior Software Engineer, Fintech	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Optasia</b>
# <span class="jb-loc t-mute t-nowrap u-block">Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# ; collection. We provide a versatile <b>AI</b> Platform powering financial inclusion, delivering ... do As a Senior Software <b>engineer</b> you will be involved with ...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 15 hours ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70949733" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70949733" data-js-jobheartstatus="" data-savelinklatter="70949733" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-machine-learning-engineer-70949733/">
# Senior Machine Learning Engineer	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Neworleansbio</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Senior Machine Learning <b>Engineer</b> Full-time Job Description As ... a Senior Machine Learning <b>Engineer</b> on our ML Platform team ... of services needed to release <b>AI</b> and data science	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 11 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70988981" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70988981" data-js-jobheartstatus="" data-savelinklatter="70988981" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/ai-team-leader-70988981/">
# AI Team leader	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">PaxeraHealth</b>
# <span class="jb-loc t-mute t-nowrap u-block">Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# Job Overview: We are seeking a highly skilled and experienced AI team leader to lead our medical imaging AI development team. The…	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 2 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70985582" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70985582" data-js-jobheartstatus="" data-savelinklatter="70985582" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/devops-senior-engineer-70985582/">
# DevOps Senior Engineer	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Al Ahly Momkn​</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# A subsidiary of Al Ahly Capital, Al Ahly Momkn is a fast-evolving Fin-tech company committed to promoting secure, convenient &amp;…	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 4 days ago	</div>
# </div>
# </div>
# </li>
# <li class="p0">
# <div class="p20 bg-inverse t-center no-print" id="ad_listing_1"></div> </li>
# <li class="has-pointer-d" data-job-id="70986042" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70986042" data-js-jobheartstatus="" data-savelinklatter="70986042" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/devops-lead-70986042/">
# DevOps Lead	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Al Ahly Momkn​</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# ​A subsidiary of Al Ahly Capital, Al Ahly Momkn is a fast-evolving Fin-tech company committed to promoting secure, convenient &amp;…	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 4 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70985712" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70985712" data-js-jobheartstatus="" data-savelinklatter="70985712" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-software-engineer-backend-70985712/">
# Senior Software Engineer (Backend)	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Shahry</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# looking for a Senior Software <b>Engineer</b> to join our Backend Team ... ! About Shahry Shahry is an <b>AI</b> powered mobile credit card. Launched ... experience as a Senior Software <b>Engineer</b>...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 4 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70985743" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70985743" data-js-jobheartstatus="" data-savelinklatter="70985743" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/software-quality-engineer-70985743/">
# Software Quality Engineer	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Shahry</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# a Software Quality Assurance (QA) <b>engineer</b> who will manage exploratory and ... . About Shahry Shahry is an <b>AI</b> powered mobile credit card. Launched ... of working on a QA <b>Engineer</b>...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 4 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70985780" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70985780" data-js-jobheartstatus="" data-savelinklatter="70985780" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/software-engineer-backend-70985780/">
# Software Engineer (Backend)	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Shahry</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# are looking for a Software <b>Engineer</b> to join our Web Team ... ! About Shahry Shahry is an <b>AI</b> powered mobile credit card. Launched ...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 4 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70985527" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70985527" data-js-jobheartstatus="" data-savelinklatter="70985527" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/site-reliability-engineer-70985527/">
# Site Reliability Engineer	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Shahry</b>
# <span class="jb-loc t-mute t-nowrap u-block">Cairo, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# looking for a Site Reliability <b>Engineer</b> to join our team. If ... ! About Shahry Shahry is an <b>AI</b> powered mobile credit card. Launched ...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 4 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70914045" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70914045" data-js-jobheartstatus="" data-savelinklatter="70914045" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/sr-machine-learning-engineer-gcp-70914045/">
# Sr Machine Learning Engineer (GCP)	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">Rackspace</b>
# <span class="jb-loc t-mute t-nowrap u-block">Alexandria, Egypt</span>
# </div>
# </div>
# </div>
# <div class="jb-descr m10t t-small">
# a seasoned Senior Machine Learning <b>Engineer</b> to enhance our talented team ... vertexAI, Automl and other GCP <b>AI</b> and Machine learning services. Experience ...	</div>
# <div class="jb-footer row is-m h-align-left m10t is-m v-align-center">
# <div class="jb-date p0x t-xsmall t-mute m10r">
# 19 days ago	</div>
# </div>
# </div>
# </li>
# <li class="has-pointer-d" data-job-id="70602682" data-js-job="">
# <div class="jb-save u-right">
# <a class="toggler-inactive" data-js-jobheart="" data-js-jobheartid="70602682" data-js-jobheartstatus="" data-savelinklatter="70602682" data-toggler='{"inactive":true}' href="javascript:;">
# <i class="icon t-danger is-heart-solid is-20 m0"></i>
# <i class="icon is-heart is-20 m0 t-mute"></i>
# </a>
# </div>
# <div>
# <div class="p0 m0 no-wrap is-m row v-align-center">
# <div class="p20r u-stretch">
# ...
# <div class="accordion-animate">
# <div class="accordion-content">
# <ul class="list is-basic is-spaced is-compact t-small m0">
# <li>
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" href="/en/egypt/jobs/ai-engineer-jobs/">
# All	</a>
# </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_location_lc_id"}' href="/en/egypt/jobs/ai-engineer-jobs-in-new-cairo-cairo/">
# New Cairo	</a>
#  <span class="t-mute">(1)</span> </li>
# </ul>
# </div>
# </div>
# <input checked="checked" class="accordion-toggle" id="jb_industry_id_original" type="checkbox"/>
# <label class="accordion-title" for="jb_industry_id_original">Industry</label>
# <div class="accordion-animate">
# <div class="accordion-content">
# <ul class="list is-basic is-spaced is-compact t-small m0">
# <li>
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" href="/en/egypt/jobs/ai-engineer-jobs/">
# All	</a>
# </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_industry_id_original"}' href="/en/egypt/jobs/ai-engineer-jobs/?filters%5Bjb_industry_id_original%5D%5B%5D=33" rel="nofollow">
# Other Business Support Services	</a>
#  <span class="t-mute">(40)</span> </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_industry_id_original"}' href="/en/egypt/jobs/ai-engineer-jobs/?filters%5Bjb_industry_id_original%5D%5B%5D=17" rel="nofollow">
# General Engineering Consultancy	</a>
#  <span class="t-mute">(10)</span> </li>
# </ul>
# </div>
# </div>
# <input class="accordion-toggle" id="jb_gender_int" type="checkbox"/>
# <label class="accordion-title" for="jb_gender_int">Gender</label>
# <div class="accordion-animate">
# <div class="accordion-content">
# <ul class="list is-basic is-spaced is-compact t-small m0">
# <li>
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" href="/en/egypt/jobs/ai-engineer-jobs/">
# All	</a>
# </li>
# <li class="t-small">
# <a class="jsAjaxLoad" data-close-sheet="" data-js-filter="" data-js-params='{"clickedFacet":"jb_gender_int"}' href="/en/egypt/jobs/ai-engineer-jobs/?filters%5Bjb_gender_int%5D%5B%5D=0" rel="nofollow">
# Gender Unspecified	</a>
#  <span class="t-mute">(50)</span> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form> </div>
# </div>
# </div>
# </aside>
# </div>
# <div class="can-toggle is-m m" data-toggle-sheet="{&quot;on&quot;:{&quot;afterclose&quot;:&quot;B8.resolve(B8.ToggleSheet, '#jobAlertSheet').dispose()&quot;}}" id="jobAlertSheet">
# <div class="toggle-head">
# <a class="m" data-close-sheet="" data-sheet-focus-m="" href="javascript:;" onclick="uncheckSwtichJobAlert()"><b class="t-mute">Cancel</b></a>
# </div>
# <div class="toggle-content">
# <div class="box">
# <div class="row h-align-center">
# <div class="col is-8-d">
# <div id="modalSheetContent"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="p40y-d p20y-m bg-inverse" id="clusterRelatedSearches">
# <div class="box">
# <h3 class="m40b t-center">People also search for...</h3>
# <ul class="media-list is-spaced is-divided" data-empty="Nothing available">
# <li>
# <ul class="list is-tabular of-3-d of-1-m">
# <li class="t-nowrap"><a href="/en/egypt/jobs/hospitality-iiii-tourism-and-travel-professionals-jobs-in-cairo/" title="Hospitality IIII  Tourism and Travel Professionals Jobs in Cairo">Hospitality IIII Tourism and Travel Professionals Jobs in Cairo</a></li>
# <li class="t-nowrap"><a href="/en/egypt/jobs/hospitality-iiii-tourism-and-travel-professionals-jobs-in-alexandria/" title="Hospitality IIII  Tourism and Travel Professionals Jobs in Alexandria">Hospitality IIII Tourism and Travel Professionals Jobs in Alexandria</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </section>
# <div class="u-none" id="tmplMsg">
# <div class="msg is-success">
# <span class="js-replace"></span>
# <div class="msg-actions">
# <a class="btn is-small is-inverse" href="/en/jobseeker/my-account/subscriptions-update/" target="_blank"> MANAGE</a>
# </div>
# <button class="msg-close" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="successMsg">
# <div class="msg is-default m20b-d">
# The job is now saved to your saved jobs successfully	<div class="msg-actions">
# <a class="is-inverse" href="https://www.bayt.com/en/international/jobs/?options%5Bis_saved_jobs%5D=1">Manage</a>
# </div>
# <button class="msg-close t-inverse" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="alertMsg">
# <div class="msg is-default snackbar m20b-d" data-automation-id="similarJobEnableClassicView">
# Similar jobs alert created successfully. You can manage alerts in settings.	<div class="msg-actions">
# <a class="is-inverse" href="/en/jobseeker/my-account/subscriptions-update/">MANAGE</a>
# </div>
# <button class="msg-close t-inverse" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="warnMsg">
# <div class="msg is-warning">
# You have reached your limit of 15 Job Alerts. To create a new Job Alert, delete one of your existing Job Alerts first.	<div class="msg-actions">
# <a class="btn is-small is-inverse" href="/en/jobseeker/my-account/subscriptions-update/" target="_blank"> MANAGE</a>
# </div>
# <button class="msg-close" data-attach-close=""></button>
# </div>
# </div>
# <div class="u-none" id="bellDisableMsg">
# <div class="msg is-default snackbar m20b-d is-stretched">
# Similar jobs alert disabled successfully. You can manage alerts in settings.	<div class="msg-actions">
# <a class="is-inverse" href="/en/jobseeker/my-account/subscriptions-update/">MANAGE</a>
# </div>
# <button class="msg-close t-inverse" data-attach-close=""></button>
# </div>
# </div>
# <footer class="u-rel bt m0" id="footer">
# <div class="box is-large">
# <div id="pageBreadcrumbs">
# <div class="row p10y">
# <div class="col">
# <ol class="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="https://www.bayt.com/" itemprop="item" title="Home"><span itemprop="name">Home</span></a><meta content="1" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="/en/egypt/jobs/search/" itemprop="item" title="Jobs"><span itemprop="name">Jobs</span></a><meta content="2" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="/en/egypt/jobs/" itemprop="item" title="Egypt Jobs"><span itemprop="name">Egypt Jobs</span></a><meta content="3" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="/en/egypt/jobs/data-scientist-jobs/" itemprop="item" title="Data Scientist Jobs"><span itemprop="name">Data Scientist Jobs</span></a><meta content="4" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><span itemprop="name">Ai Engineer Jobs in Egypt</span><meta content="5" itemprop="position"/></li> </ol> </div>
# </div>
# <hr/>
# </div> <div class="row p10y">
# <div class="col">
# <div class="t-large t-bold m20b">Find Jobs</div>
# <ul class="list is-basic is-cols of-6-d of-2-m t-small" id="yw1">
# <li><a class="t-default" href="https://www.bayt.com/en/uae/jobs/jobs-in-abu-dhabi/"> Jobs in Abu Dhabi</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/uae/jobs/jobs-in-dubai/"> Jobs in Dubai</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/algeria/jobs/"> Jobs in Algeria</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/bahrain/jobs/"> Jobs in Bahrain</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/egypt/jobs/"> Jobs in Egypt</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/india/jobs/"> Jobs in India</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/iraq/jobs/"> Jobs in Iraq</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/jordan/jobs/"> Jobs in Jordan</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/kuwait/jobs/"> Jobs in Kuwait</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/lebanon/jobs/"> Jobs in Lebanon</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/libya/jobs/"> Jobs in Libya</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/morocco/jobs/"> Jobs in Morocco</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/oman/jobs/"> Jobs in Oman</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/pakistan/jobs/"> Jobs in Pakistan</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/qatar/jobs/"> Jobs in Qatar</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/saudi-arabia/jobs/"> Jobs in Saudi Arabia</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/tunisia/jobs/"> Jobs in Tunisia</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/uae/jobs/"> Jobs in UAE</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/yemen/jobs/"> Jobs in Yemen</a></li>
# </ul> </div>
# </div>
# <hr/>
# <div class="row p10y is-reversed-m">
# <div class="col is-4-d">
# <div class="t-large t-bold m20b">About Bayt.com</div>
# <div class="t-small p10r">Bayt.com is the leading job site in the Middle East and North Africa, connecting job seekers with employers looking to hire. Every day, thousands of new job vacancies are listed on the award-winning platform from the region's top employers.</div>
# <div class="t-large t-bold m20y">Follow Bayt.com</div>
# <ul class="list col is-6-d is-8-m is-basic is-cols of-6 m0b" id="yw2">
# <li><a aria-label="Facebook" class="m0 icon is-18 is-facebook t-default" href="https://www.facebook.com/Baytcom"></a></li>
# <li><a aria-label="Twitter" class="m0 icon is-18 is-twitter t-default" href="https://twitter.com/Baytcom"></a></li>
# <li><a aria-label="LinkedIn" class="m0 icon is-18 is-linkedin t-default" href="https://www.linkedin.com/company/bayt.com"></a></li>
# <li><a aria-label="YouTube" class="m0 icon is-18 is-youtube t-default" href="https://www.youtube.com/Baytcom"></a></li>
# <li><a aria-label="Instagram" class="m0 icon is-18 is-instagram t-default" href="https://www.instagram.com/baytcom/"></a></li>
# <li><a aria-label="Pinterest" class="m0 icon is-18 is-pinterest t-default" href="https://www.pinterest.com/baytcom/"></a></li>
# </ul> </div>
# <div class="col is-2-d">
# <div class="t-large t-bold m20b">Company</div>
# <ul class="list is-basic t-small m0b" id="yw3">
# <li><a class="t-default" href="https://www.bayt.com/en/about/">About Us</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/pages/contact-us/">Contact Us</a></li>
# <li><a class="t-default" href="https://careers.bayt.com/en/job-search-results/">Careers</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/about/press/">Press Corner</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/advertise/">Advertise With Us</a></li>
# </ul> </div>
# <div class="col is-2-d">
# <div class="t-large t-bold m20b">Quick Links</div>
# <ul class="list is-basic t-small m0b" id="yw4">
# <li><a class="t-default" href="https://www.bayt.com/en/blog/">Blog</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/feedback/submit/">Help Center</a></li>
# <li><a class="t-default" href="https://www.bayt.com/en/affiliates/">Affiliate Program</a></li>
# </ul> </div>
# <div class="col is-4-d">
# <div class="t-large t-bold m20b">Get the Bayt App</div>
# <div class="u-flex">
# <a class="m5r" href="https://play.google.com/store/apps/details?id=com.bayt" target="_blank">
# <img alt="Google Play" class="img-logo is-GooglePlay" height="30.622" loading="lazy" src="..." width="106"/>
# </a>
# <a href="https://apps.apple.com/us/app/bayt-com-job-search/id510893233" target="_blank">
# <img alt="App Store" class="img-logo is-AppStore" height="30.622" loading="lazy" src="..." width="106"/>
# </a>
# </div>
# <div class="row no-wrap m20t d">
# <img alt="Bayt App QR Code" data-src="//secure.b8cdn.com/bayt/assets/b8static/svg/qr-footer.svg" height="75" loading="lazy" src="..." width="75"/>
# <div class="m5l">
# <p class="m0 t-mute t-small">Scan the QR code to get the app</p>
# <img alt="arrow pointer" data-src="//secure.b8cdn.com/bayt/assets/b8static/png/footer/arrowRight.png" height="30" loading="lazy" src="..." width="30"/>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="row">
# <div class="col is-8-d t-small">
# © <b>2024 Bayt.com, Inc.</b> All Rights Reserved. <br/>
# <a class="t-default" href="https://www.bayt.com/en/pages/terms/">Terms of Use</a> ·
# <a class="t-default" href="https://www.bayt.com/en/pages/privacy-statement/"> Privacy Policy </a> ·
# <a class="t-default" href="https://www.bayt.com/en/pages/cookie-policy/"> Cookie Policy </a> ·
# <a class="t-default" href="https://www.bayt.com/en/pages/security-message/"> Security Message </a>
# </div>
# <div class="col is-4-d t-right-d">
# <div class="popover-owner u-iblock" data-popover='{"trigger":"click"}'>
# <div class="btn is-secondary is-outline">English<i class="icon is-internet m0 m10l"></i></div>
# <div class="popover" data-placement="tr">
# <ul class="dropdown">
# <li><a class="t-nowrap" href="/fr/egypt/jobs/Ai+Engineer-jobs/" rel="nofollow">Français</a></li>
# <li class="has-divider"><a class="t-nowrap" href="/ar/egypt/jobs/Ai+Engineer-jobs/">العربية</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer><noscript data-deferred-styles=""><link href="https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/css/B8J.css" media="all" rel="stylesheet" type="text/css"/></noscript> <script defer="defer" id="3561365188" src="https://secure.b8cdn.com/bayt/assets/job-7ocrm4q9/js/JobSearchClassic.js"></script>
# <script async="async" id="3804486059" src="https://www.googletagmanager.com/gtm.js?id=GTM-NW36N4"></script>
# <script>function i(url,attrs){var script=document.createElement("script");script.src=url;for(var key in attrs){script.setAttribute(key,attrs[key]||"");}document.head.appendChild(script);}try{eval("var foo=(x)=>x+1");i("https:\/\/secure.b8cdn.com\/bayt\/assets\/baytui-8ebnt3um\/js\/B8com.es6.js",{"type":null,"defer":true,"id":789058945});}catch(e){i("\/bayt\/assets\/baytui-8ebnt3um\/js\/B8com.js",{"type":null,"defer":true,"id":789058945});}</script>
# <script defer="defer">var navStatusCookie=document.cookie.split("; ").find((row)=>row.startsWith("nav-status="))?.split("=")[1];const csaScript=document.createElement("script");csaScript.async=true;csaScript.src="https://secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/js/adsenseCSA.js";if(navStatusCookie){if(navStatusCookie.includes("upgrade")){document.addEventListener("DOMContentLoaded",function(event){csaScript.addEventListener("load",()=>{adsenseCSA.run();})
# document.body.appendChild(csaScript);})}}else{document.addEventListener("DOMContentLoaded",function(event){csaScript.addEventListener("load",()=>{adsenseCSA.run();})
# document.body.appendChild(csaScript);})}</script>
# <script async="async">var navStatusCookie=document.cookie.split("; ").find((row)=>row.startsWith("nav-status="))?.split("=")[1];const gptScript=document.createElement("script");gptScript.async=true;gptScript.src="https://securepubads.g.doubleclick.net/tag/js/gpt.js";if(navStatusCookie){if(navStatusCookie.includes("upgrade")){document.body.appendChild(gptScript);}}else{document.body.appendChild(gptScript);}</script>
# <script>B8.ready(function(){BaytNavigation.ajax.defaultAjaxSetup()});if(typeof window.CustomEvent!=='function'||(window.Element&&!Element.prototype.closest)||!Element.prototype.matches||typeof Object.assign!=='function'||!Array.prototype.find||!Array.prototype.findIndex)document.write('<script src="'+(function(){"use strict";try{eval("var foo=(x)=>x+1");}catch(e){return'//secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/js/Polyfills.js';}return'//secure.b8cdn.com/bayt/assets/baytui-8ebnt3um/js/Polyfills.es6.js';})()+'" defer="defer"><\/script>');var dataLayer=dataLayer||[];dataLayer.push({"pageLang":"en","pageName":null,"pageSection":"Job Seeker","pageProtected":false});dataLayer.push({"gtm.start":new Date().getTime(),"event":"gtm.js"});B8.ready(function(){try{(JobSearch.init)()}catch(err){console.error(err)};});</script>
# </body>
# </html>

# %%
job = website.find("div",class_="p20r u-stretch")
job
# Out:
# <div class="p20r u-stretch">
# <h2 class="jb-title m0 t-large m20r p40r t-nowrap">
# <a data-js-aid="jobID" data-js-link="" href="/en/egypt/jobs/senior-ai-engineer-70988978/">
# Senior AI Engineer	</a>
# </h2>
# <div class="jb-company-loc t-small m20r p40r t-nowrap">
# <b class="jb-company t-nowrap">PaxeraHealth</b>
# <span class="jb-loc t-mute t-nowrap u-block">Egypt</span>
# </div>
# </div>

# %%
jobname=job.find("h2",class_="jb-title m0 t-large m20r p40r t-nowrap").text
jobname
# Out:
# '\n\nSenior AI Engineer\t\n'

# %%
jobcompany=job.find("b",class_="jb-company t-nowrap").text
jobcompany
# Out:
# 'PaxeraHealth'

# %%
joblocation=job.find("span",class_="jb-loc t-mute t-nowrap u-block").text
joblocation
# Out:
# 'Egypt'

# %%
jobs = website.find_all("div",class_="p20r u-stretch")
for job in jobs:
    jobname=job.find("h2",class_="jb-title m0 t-large m20r p40r t-nowrap").text
    jobcompany=job.find("b",class_="jb-company t-nowrap").text
    joblocation=job.find("span",class_="jb-loc t-mute t-nowrap u-block").text
    print(jobname,jobcompany,joblocation)
# Out:
# Senior AI Engineer
#  PaxeraHealth Egypt
#
#
# Senior Software Engineer - AI Training - Remote
#  Remotebase Cairo, Egypt
#
#
# AI Software Engineer - [Backend]
#  Envisions Employment Solutions Cairo, Egypt
#
#
# Senior Machine Learning Engineer
#  Procore Technologies, Inc Cairo, Egypt
#
#
# Senior Software Engineer (Python)
#  Clarivate Alexandria, Egypt
#
#
# Engineering Manager-Outsystems – Egypt
#  Linkdev Egypt
#
#
# Senior Software Engineer, Fintech
#  Optasia Egypt
#
#
# Senior Machine Learning Engineer
#  Neworleansbio Cairo, Egypt
#
#
# AI Team leader
#  PaxeraHealth Egypt
#
#
# DevOps Senior Engineer
#  Al Ahly Momkn​ Cairo, Egypt
#
#
# DevOps Lead
#  Al Ahly Momkn​ Cairo, Egypt
#
#
# Senior Software Engineer (Backend)
#  Shahry Cairo, Egypt
#
#
# Software Quality Engineer
#  Shahry Cairo, Egypt
#
#
# Software Engineer (Backend)
#  Shahry Cairo, Egypt
#
#
# Site Reliability Engineer
#  Shahry Cairo, Egypt
#
#
# Sr Machine Learning Engineer (GCP)
#  Rackspace Alexandria, Egypt
#
#
# Senior Machine Learning Engineer
#  LXT Egypt
#
#
# Software Engineering Manager
#  Microsoft Cairo, Egypt
#
#
# Tech Innovation - Sr. R&D Software Engineer - Cairo
#  Infomineo Cairo, Egypt
#
#
# Tech Innovation - Sr. R&D Software Engineer - Cairo
#  Infomineo Egypt

# %%
import csv

# %%
csvfile= open("AIjobs_Egypt.csv","w", encoding='utf-8')
writer= csv.writer(csvfile)

# %%
writer.writerow(["job_name","company_name","company_location"])
# Out:
# 40

# %%
jobs=website.find_all("div",class_="p20r u-stretch")
for job in jobs:
    jobname=job.find("h2",class_="jb-title m0 t-large m20r p40r t-nowrap").text
    jobcompany=job.find("b",class_="jb-company t-nowrap").text
    joblocation=job.find("span",class_="jb-loc t-mute t-nowrap u-block").text
    writer.writerow([jobname,jobcompany,joblocation])
csvfile.close()
